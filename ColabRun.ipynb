# %% [markdown]
# <a href="https://colab.research.google.com/github/invisioncoai-a11y/MachineProject/blob/main/ColabRun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) تثبيت المكتبات
# !python -m pip install -q numpy pandas matplotlib scikit-learn opencv-python-headless torch torchvision pillow tqdm

# %%
# 2) ربط Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 3) ارجع لمجلد آمن
import os
os.chdir('/content')
print("Current dir:", os.getcwd())
# Out:
# Current dir: /content

# %%
# 4) حذف النسخة القديمة ثم سحب آخر نسخة من GitHub
# !rm -rf /content/MachineProject
# !git clone https://github.com/invisioncoai-a11y/MachineProject.git
# Out:
# Cloning into 'MachineProject'...
# remote: Enumerating objects: 11089, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 11089 (delta 6), reused 18 (delta 4), pack-reused 11063 (from 1)
# Receiving objects: 100% (11089/11089), 129.16 MiB | 21.86 MiB/s, done.
# Resolving deltas: 100% (1067/1067), done.

# %%
# 5) تعريف المسارات
import os
import sys

PROJECT_ROOT = "/content/MachineProject/code"
DATASET_ZIP = "/content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip"
EXTRACTED_DATASET_DIR = "/content/local_dataset"
REPORTS_DIR = "/content/reports"

print("PROJECT_ROOT =", PROJECT_ROOT)
print("DATASET_ZIP =", DATASET_ZIP)
print("EXTRACTED_DATASET_DIR =", EXTRACTED_DATASET_DIR)
print("REPORTS_DIR =", REPORTS_DIR)

if not os.path.exists(DATASET_ZIP):
    raise FileNotFoundError(f"Dataset zip not found: {DATASET_ZIP}")
# Out:
# PROJECT_ROOT = /content/MachineProject/code
# DATASET_ZIP = /content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip
# EXTRACTED_DATASET_DIR = /content/local_dataset
# REPORTS_DIR = /content/drive/MyDrive/ML project/reports

# %%
# 6) تجهيز الداتا والـ reports
# !rm -rf "/content/local_dataset"
# !mkdir -p "/content/local_dataset"
# !unzip -q -o "/content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip" -d "/content/local_dataset"

# %%
# 7) ضبط متغيرات البيئة
os.environ["PROJECT_ROOT"] = PROJECT_ROOT
os.environ["DATASET_ZIP"] = DATASET_ZIP
os.environ["EXTRACTED_DATASET_DIR"] = EXTRACTED_DATASET_DIR
os.environ["REPORTS_DIR"] = REPORTS_DIR

# مهم للـ imports
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Environment variables set.")
print("PYTHONPATH ready.")
# Out:
# Environment variables set.
# PYTHONPATH ready.

# %%
# 8) فحص سريع
# !find /content/MachineProject/code -maxdepth 3 -type f | sort | head -200
# Out:
# /content/MachineProject/code/DAL/core_data.py
# /content/MachineProject/code/DAL/eda/explore_dataset.py
# /content/MachineProject/code/DAL/eda/explore_lesions.py
# /content/MachineProject/code/DAL/eda/__init__.py
# /content/MachineProject/code/DAL/__init__.py
# /content/MachineProject/code/DAL/preparation/config.py
# /content/MachineProject/code/DAL/preparation/data_loader.py
# /content/MachineProject/code/DAL/preparation/__init__.py
# /content/MachineProject/code/DAL/preparation/lesion_manifest.py
# /content/MachineProject/code/DAL/preparation/lesion_utils.py
# /content/MachineProject/code/DAL/preparation/paths.py
# /content/MachineProject/code/DAL/preparation/pool_manager.py
# /content/MachineProject/code/DAL/preparation/split_data.py
# /content/MachineProject/code/Models/classes/hybrid_model.py
# /content/MachineProject/code/Models/classes/__init__.py
# /content/MachineProject/code/Models/core_models.py
# /content/MachineProject/code/Models/__init__.py
# /content/MachineProject/code/Models/operations/__init__.py
# /content/MachineProject/code/Models/operations/model_ops.py
# /content/MachineProject/code/RUN.py

# %%
# 9) الدخول لمجلد الكود
# %cd /content/MachineProject/code
# !pwd
# !ls -la
# Out:
# /content/MachineProject/code
# /content/MachineProject/code
# total 20
# drwxr-xr-x 4 root root 4096 Apr 24 17:39 .
# drwxr-xr-x 4 root root 4096 Apr 24 17:39 ..
# drwxr-xr-x 5 root root 4096 Apr 24 17:39 DAL
# drwxr-xr-x 4 root root 4096 Apr 24 17:39 Models
# -rw-r--r-- 1 root root  749 Apr 24 17:39 RUN.py

# %%
# 10) اختبار imports الأساسية قبل التشغيل
import torch
import cv2
import pandas as pd
import numpy as np
from PIL import Image
from torchvision import transforms

print("torch version:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("basic imports OK")
# Out:
# torch version: 2.10.0+cu128
# cuda available: True
# basic imports OK

# %%
# 11) تشغيل المشروع
# !python RUN.py
# Out:
# ===== STARTING FULL PIPELINE =====
#
# ===== EDA PIPELINE =====
# EDA outputs saved to: /content/drive/MyDrive/ML project/reports/eda
#
# ===== IMAGE POOL MANAGER: INITIALIZED =====
# Annotations dir: /content/drive/MyDrive/ML project/reports/annotations
# Labeled images: 745
# Unlabeled images: 14159
# Val images: 1864
# Test images: 1864
#
# ===== IMAGE-LEVEL DATA PIPELINE =====
# Project root: /content/MachineProject/code
# Dataset root: /content/local_dataset
# Train CSV: /content/local_dataset/train.csv
# Train dir: /content/local_dataset/train_images
# Test dir: /content/local_dataset/test_images
# Reports dir: /content/drive/MyDrive/ML project/reports
# Metadata path: /content/drive/MyDrive/ML project/reports/metadata/pipeline_metadata.json
#
# --- Image-level shapes ---
# Train: (18632, 13)
# Train pool: (16768, 13)
# Validation: (1864, 13)
# Test: (1864, 13)
# Initial labeled: (745, 13)
# Unlabeled pool: (14159, 13)
#
# --- Pool state ---
# Pool labeled: (745, 13)
# Pool unlabeled: (14159, 13)
#
# ===== DATA PIPELINE FINISHED =====
# Reports dir: /content/drive/MyDrive/ML project/reports
# Metadata path: /content/drive/MyDrive/ML project/reports/metadata/pipeline_metadata.json
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:00<00:00, 168MB/s]
#
# ===== MODEL PIPELINE =====
# Device: cuda
# Classes: ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# Trainable params: 28349798
# train loader size: 745
# unlabeled loader size: 14159
# val loader size: 1864
# test loader size: 1864
#
# [ERROR] Pipeline failed:
# Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/worker.py", line 358, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 57, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 401, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 172, in collate
#     key: collate(
#          ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 155, in collate
#     return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 275, in collate_tensor_fn
#     return torch.stack(batch, 0, out=out)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: stack expects each tensor to be equal size, but got [2672, 4000] at entry 0 and [3000, 4000] at entry 6
#
# Traceback (most recent call last):
#   File "/content/MachineProject/code/RUN.py", line 29, in <module>
#     main()
#   File "/content/MachineProject/code/RUN.py", line 17, in main
#     model_outputs = run_model_pipeline(pipeline_bundle)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MachineProject/code/Models/operations/model_ops.py", line 66, in run_model_pipeline
#     batch = next(iter(loaders["train"]))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1548, in _next_data
#     return self._process_data(data, worker_id)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1586, in _process_data
#     data.reraise()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_utils.py", line 775, in reraise
#     raise exception
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/worker.py", line 358, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 57, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 401, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 172, in collate
#     key: collate(
#          ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 155, in collate
#     return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/collate.py", line 275, in collate_tensor_fn
#     return torch.stack(batch, 0, out=out)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: stack expects each tensor to be equal size, but got [2672, 4000] at entry 0 and [3000, 4000] at entry 6

# %%
# !find /content/reports -maxdepth 4 -type f | sort | head -200

# %%
# !zip -r /content/reports.zip /content/reports
# Out:
# updating: content/reports/ (stored 0%)

# %%
from google.colab import files
files.download("/content/reports.zip")
