# %% [markdown]
# <a href="https://colab.research.google.com/github/invisioncoai-a11y/MachineProject/blob/main/ColabRun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/invisioncoai-a11y/MachineProject.git
# Out:
# Cloning into 'MachineProject'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# %cd /content/MachineProject
# Out:
# /content/MachineProject

# %%
import os
import sys

PROJECT_ROOT = "/content/MachineProject"
LOCAL_DATA_ROOT = "/content/local_dataset"
DRIVE_ZIP_PATH = "/content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip"
REPORTS_DIR = "/content/drive/MyDrive/ML project/reports"

os.makedirs(LOCAL_DATA_ROOT, exist_ok=True)
os.makedirs(REPORTS_DIR, exist_ok=True)

sys.path.append(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

print("PROJECT_ROOT =", PROJECT_ROOT)
print("LOCAL_DATA_ROOT =", LOCAL_DATA_ROOT)
print("DRIVE_ZIP_PATH =", DRIVE_ZIP_PATH)
print("REPORTS_DIR =", REPORTS_DIR)
# Out:
# PROJECT_ROOT = /content/MachineProject
# LOCAL_DATA_ROOT = /content/local_dataset
# DRIVE_ZIP_PATH = /content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip
# REPORTS_DIR = /content/drive/MyDrive/ML project/reports

# %%
# !pip install numpy pandas matplotlib scikit-learn opencv-python torch torchvision

# %%
# !unzip -q -o "/content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip" -d "/content/local_dataset"

# %%
import os

os.environ["PROJECT_ROOT"] = "/content/MachineProject"
os.environ["DATASET_ZIP"] = "/content/drive/MyDrive/ML project/Plant Pathology 2021 - FGVC8 Dataset/plant-pathology-2021-fgvc8.zip"
os.environ["EXTRACTED_DATASET_DIR"] = "/content/local_dataset"
os.environ["REPORTS_DIR"] = "/content/drive/MyDrive/ML project/reports"

print("Environment variables set.")

# %%
# !python RUN.py
