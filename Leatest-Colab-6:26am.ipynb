# %% [markdown]
# <a href="https://colab.research.google.com/github/invisioncoai-a11y/MachineProject/blob/main/Leatest-Colab-6%3A26am.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) تثبيت المكتبات
# !python -m pip install -q numpy pandas matplotlib scikit-learn opencv-python-headless torch torchvision pillow tqdm

# %%
# 2) ربط Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls -lh "/content/drive/MyDrive/Colab Notebooks"
# Out:
# total 15G
# -rw------- 1 root root  15G Apr 24 22:49 plant-pathology-2021-fgvc8.zip
# -rw------- 1 root root 9.0K Apr 24 23:01 Untitled0.ipynb

# %%
# 3) ارجع لمجلد آمن
import os
os.chdir('/content')
print("Current dir:", os.getcwd())
# Out:
# Current dir: /content

# %%
# 4) حذف النسخة القديمة ثم سحب آخر نسخة من GitHub
# !rm -rf /content/MachineProject
# !git clone https://github.com/invisioncoai-a11y/MachineProject.git
# Out:
# Cloning into 'MachineProject'...
# remote: Enumerating objects: 11113, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 11113 (delta 18), reused 33 (delta 10), pack-reused 11063 (from 1)
# Receiving objects: 100% (11113/11113), 129.17 MiB | 22.01 MiB/s, done.
# Resolving deltas: 100% (1079/1079), done.

# %%
# 5) تعريف المسارات
import os
import sys

PROJECT_ROOT = "/content/MachineProject/code"
DATASET_ZIP = "/content/drive/MyDrive/Colab Notebooks/plant-pathology-2021-fgvc8.zip"
EXTRACTED_DATASET_DIR = "/content/local_dataset"
REPORTS_DIR = "/content/reports"

print("PROJECT_ROOT =", PROJECT_ROOT)
print("DATASET_ZIP =", DATASET_ZIP)
print("EXTRACTED_DATASET_DIR =", EXTRACTED_DATASET_DIR)
print("REPORTS_DIR =", REPORTS_DIR)

if not os.path.exists(DATASET_ZIP):
    raise FileNotFoundError(f"Dataset zip not found: {DATASET_ZIP}")
# Out:
# PROJECT_ROOT = /content/MachineProject/code
# DATASET_ZIP = /content/drive/MyDrive/Colab Notebooks/plant-pathology-2021-fgvc8.zip
# EXTRACTED_DATASET_DIR = /content/local_dataset
# REPORTS_DIR = /content/reports

# %%
# 6) تجهيز الداتا والـ reports
# !rm -rf "/content/local_dataset"
# !mkdir -p "/content/local_dataset"
# !unzip -q -o "/content/drive/MyDrive/Colab Notebooks/plant-pathology-2021-fgvc8.zip" -d "/content/local_dataset"

# %%
# 7) ضبط متغيرات البيئة
os.environ["PROJECT_ROOT"] = PROJECT_ROOT
os.environ["DATASET_ZIP"] = DATASET_ZIP
os.environ["EXTRACTED_DATASET_DIR"] = EXTRACTED_DATASET_DIR
os.environ["REPORTS_DIR"] = REPORTS_DIR

# مهم للـ imports
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Environment variables set.")
print("PYTHONPATH ready.")
# Out:
# Environment variables set.
# PYTHONPATH ready.

# %%
# 8) فحص سريع
# !find /content/MachineProject/code -maxdepth 3 -type f | sort | head -200
# Out:
# /content/MachineProject/code/DAL/core_data.py
# /content/MachineProject/code/DAL/eda/explore_dataset.py
# /content/MachineProject/code/DAL/eda/explore_lesions.py
# /content/MachineProject/code/DAL/eda/__init__.py
# /content/MachineProject/code/DAL/__init__.py
# /content/MachineProject/code/DAL/preparation/config.py
# /content/MachineProject/code/DAL/preparation/data_loader.py
# /content/MachineProject/code/DAL/preparation/__init__.py
# /content/MachineProject/code/DAL/preparation/lesion_manifest.py
# /content/MachineProject/code/DAL/preparation/lesion_utils.py
# /content/MachineProject/code/DAL/preparation/paths.py
# /content/MachineProject/code/DAL/preparation/pool_manager.py
# /content/MachineProject/code/DAL/preparation/split_data.py
# /content/MachineProject/code/Models/classes/hybrid_model.py
# /content/MachineProject/code/Models/classes/__init__.py
# /content/MachineProject/code/Models/core_models.py
# /content/MachineProject/code/Models/__init__.py
# /content/MachineProject/code/Models/operations/__init__.py
# /content/MachineProject/code/Models/operations/model_ops.py
# /content/MachineProject/code/RUN.py

# %%
# 9) الدخول لمجلد الكود
# %cd /content/MachineProject/code
# !pwd
# !ls -la
# Out:
# /content/MachineProject/code
# /content/MachineProject/code
# total 20
# drwxr-xr-x 4 root root 4096 Apr 24 23:04 .
# drwxr-xr-x 4 root root 4096 Apr 24 23:04 ..
# drwxr-xr-x 5 root root 4096 Apr 24 23:04 DAL
# drwxr-xr-x 4 root root 4096 Apr 24 23:04 Models
# -rw-r--r-- 1 root root  749 Apr 24 23:04 RUN.py

# %%
# 10) اختبار imports الأساسية قبل التشغيل
import torch
import cv2
import pandas as pd
import numpy as np
from PIL import Image
from torchvision import transforms

print("torch version:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("basic imports OK")
# Out:
# torch version: 2.10.0+cu128
# cuda available: True
# basic imports OK

# %%
# 11) تشغيل المشروع
# !python RUN.py
# Out:
# ===== STARTING FULL PIPELINE =====
#
# ===== EDA PIPELINE =====
# EDA outputs saved to: /content/reports/eda
#
# ===== IMAGE POOL MANAGER: INITIALIZED =====
# Annotations dir: /content/reports/annotations
# Labeled images: 745
# Unlabeled images: 14159
# Val images: 1864
# Test images: 1864
#
# ===== IMAGE-LEVEL DATA PIPELINE =====
# Project root: /content/MachineProject/code
# Dataset root: /content/local_dataset
# Train CSV: /content/local_dataset/train.csv
# Train dir: /content/local_dataset/train_images
# Test dir: /content/local_dataset/test_images
# Reports dir: /content/reports
# Metadata path: /content/reports/metadata/pipeline_metadata.json
#
# --- Image-level shapes ---
# Train: (18632, 13)
# Train pool: (16768, 13)
# Validation: (1864, 13)
# Test: (1864, 13)
# Initial labeled: (745, 13)
# Unlabeled pool: (14159, 13)
#
# --- Pool state ---
# Pool labeled: (745, 13)
# Pool unlabeled: (14159, 13)
#
# ===== DATA PIPELINE FINISHED =====
# Reports dir: /content/reports
# Metadata path: /content/reports/metadata/pipeline_metadata.json
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
# 100% 109M/109M [00:00<00:00, 163MB/s]
#
# ===== MODEL PIPELINE =====
# Device: cuda
# Classes: ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']
# Trainable params: 28349798
# train loader size: 745
# unlabeled loader size: 14159
# val loader size: 1864
# test loader size: 1864
#
# ===== SANITY CHECK =====
# Input patches shape: (16, 6, 3, 224, 224)
# Patch mask shape: (16, 6)
# Logits shape: (16, 6)
# Embeddings shape: (16, 256)
# Prototype logits shape: (16, 6)
# Aggregated features shape: (16, 768)
# Patch features shape: (16, 6, 768)
# Target shape: (16, 6)
#
# ===== START TRAINING: ROUND 00 =====
#
# --- Epoch 1/8 ---
# train_loss=0.5922 | val_loss=0.5186 | val_acc=0.8209 | val_macro_f1=0.1873 | val_macro_precision=0.3135 | val_macro_recall=0.1847
# [BEST] New best checkpoint saved at epoch 1
#
# --- Epoch 2/8 ---
# train_loss=0.4901 | val_loss=0.4400 | val_acc=0.8637 | val_macro_f1=0.3546 | val_macro_precision=0.5858 | val_macro_recall=0.2759
# [BEST] New best checkpoint saved at epoch 2
#
# --- Epoch 3/8 ---
# train_loss=0.4193 | val_loss=0.3865 | val_acc=0.8857 | val_macro_f1=0.4852 | val_macro_precision=0.7384 | val_macro_recall=0.3692
# [BEST] New best checkpoint saved at epoch 3
#
# --- Epoch 4/8 ---
# train_loss=0.3663 | val_loss=0.3741 | val_acc=0.8909 | val_macro_f1=0.5481 | val_macro_precision=0.8032 | val_macro_recall=0.4520
# [BEST] New best checkpoint saved at epoch 4
#
# --- Epoch 5/8 ---
# train_loss=0.3515 | val_loss=0.3816 | val_acc=0.8873 | val_macro_f1=0.5951 | val_macro_precision=0.7659 | val_macro_recall=0.5252
# [BEST] New best checkpoint saved at epoch 5
#
# --- Epoch 6/8 ---
# train_loss=0.3089 | val_loss=0.3733 | val_acc=0.8878 | val_macro_f1=0.5842 | val_macro_precision=0.7369 | val_macro_recall=0.5240
#
# --- Epoch 7/8 ---
# train_loss=0.2761 | val_loss=0.3826 | val_acc=0.8936 | val_macro_f1=0.5939 | val_macro_precision=0.7874 | val_macro_recall=0.5286
#
# --- Epoch 8/8 ---
# train_loss=0.2557 | val_loss=0.3822 | val_acc=0.8912 | val_macro_f1=0.6084 | val_macro_precision=0.7753 | val_macro_recall=0.5314
# [BEST] New best checkpoint saved at epoch 8
#
# ===== TRAINING FINISHED =====
# Best epoch: 8
# Best val macro F1: 0.6084324589795931
# History CSV: /content/reports/training/round_00/history.csv
# Best checkpoint: /content/reports/training/round_00/checkpoints/best_model.pt
#
# ===== FINAL TEST EVALUATION =====
# test_loss=0.3909 | test_acc=0.8873 | test_macro_f1=0.5930 | test_macro_precision=0.7576 | test_macro_recall=0.5228
# Test metrics saved to: /content/reports/training/round_00/metrics/test_metrics.json
#
# ===== MODEL PIPELINE FINISHED =====

# %%
# !find /content/reports -maxdepth 4 -type f | sort | head -200
# Out:
# /content/reports/annotations/labeled_images.csv
# /content/reports/annotations/management/pool_state_summary.json
# /content/reports/annotations/rounds/round_00/labeled_before_training.csv
# /content/reports/annotations/rounds/round_00/round_00_summary.json
# /content/reports/annotations/rounds/round_00/unlabeled_before_query.csv
# /content/reports/annotations/test_images.csv
# /content/reports/annotations/unlabeled_images.csv
# /content/reports/annotations/val_images.csv
# /content/reports/eda/class_distribution.png
# /content/reports/eda/dataset_summary.json
# /content/reports/eda/label_combo_distribution.png
# /content/reports/eda/split_sizes.png
# /content/reports/metadata/pipeline_metadata.json
# /content/reports/splits/initial_labeled.csv
# /content/reports/splits/test.csv
# /content/reports/splits/train_full.csv
# /content/reports/splits/train_pool.csv
# /content/reports/splits/unlabeled_pool.csv
# /content/reports/splits/validation.csv
# /content/reports/training/round_00/checkpoints/best_model.pt
# /content/reports/training/round_00/checkpoints/last_model.pt
# /content/reports/training/round_00/history.csv
# /content/reports/training/round_00/history.json
# /content/reports/training/round_00/metrics/test_metrics.json
# /content/reports/training/round_00/metrics/training_summary.json
# /content/reports/training/round_00/plots/loss_curve.png
# /content/reports/training/round_00/plots/val_metrics_curve.png

# %%
# !zip -r /content/reports.zip /content/reports
# Out:
# updating: content/reports/ (stored 0%)
# updating: content/reports/training/ (stored 0%)
# updating: content/reports/training/round_00/ (stored 0%)
# updating: content/reports/training/round_00/history.csv (deflated 52%)
# updating: content/reports/training/round_00/checkpoints/ (stored 0%)
# updating: content/reports/training/round_00/checkpoints/best_model.pt (deflated 7%)
# updating: content/reports/training/round_00/checkpoints/last_model.pt (deflated 7%)
# updating: content/reports/training/round_00/history.json (deflated 73%)
# updating: content/reports/training/round_00/metrics/ (stored 0%)
# updating: content/reports/training/round_00/metrics/training_summary.json (deflated 64%)
# updating: content/reports/training/round_00/metrics/test_metrics.json (deflated 60%)
# updating: content/reports/training/round_00/plots/ (stored 0%)
# updating: content/reports/training/round_00/plots/val_metrics_curve.png (deflated 12%)
# updating: content/reports/training/round_00/plots/loss_curve.png (deflated 13%)
# updating: content/reports/splits/ (stored 0%)
# updating: content/reports/splits/train_full.csv (deflated 89%)
# updating: content/reports/splits/test.csv (deflated 88%)
# updating: content/reports/splits/unlabeled_pool.csv (deflated 88%)
# updating: content/reports/splits/initial_labeled.csv (deflated 87%)
# updating: content/reports/splits/validation.csv (deflated 87%)
# updating: content/reports/splits/train_pool.csv (deflated 88%)
# updating: content/reports/metadata/ (stored 0%)
# updating: content/reports/metadata/pipeline_metadata.json (deflated 69%)
# updating: content/reports/eda/ (stored 0%)
# updating: content/reports/eda/label_combo_distribution.png (deflated 17%)
# updating: content/reports/eda/class_distribution.png (deflated 23%)
# updating: content/reports/eda/dataset_summary.json (deflated 47%)
# updating: content/reports/eda/split_sizes.png (deflated 22%)
# updating: content/reports/annotations/ (stored 0%)
# updating: content/reports/annotations/unlabeled_images.csv (deflated 88%)
# updating: content/reports/annotations/labeled_images.csv (deflated 87%)
# updating: content/reports/annotations/val_images.csv (deflated 87%)
# updating: content/reports/annotations/test_images.csv (deflated 88%)
# updating: content/reports/annotations/management/ (stored 0%)
# updating: content/reports/annotations/management/pool_state_summary.json (deflated 47%)
# updating: content/reports/annotations/rounds/ (stored 0%)
# updating: content/reports/annotations/rounds/round_00/ (stored 0%)
# updating: content/reports/annotations/rounds/round_00/unlabeled_before_query.csv (deflated 88%)
# updating: content/reports/annotations/rounds/round_00/labeled_before_training.csv (deflated 87%)
# updating: content/reports/annotations/rounds/round_00/round_00_summary.json (deflated 47%)

# %%
# !ls -lh /content/reports.zip
# Out:
# -rw-r--r-- 1 root root 606M Apr 25 03:07 /content/reports.zip

# %%
from google.colab import files
files.download('/content/reports.zip')
